# %% [markdown]
# # NLP Lab Assignment — Experiment 2
# ## Title: Study Various Applications of NLP and Formulate a Mini-Project Problem Statement
# **Selected Mini-Project Domain:** Automated Terms & Conditions Summarizer and Clause Risk Analyzer
#
# ### Objective:
# To survey major application areas in Natural Language Processing, conduct a focused literature review on legal text processing, and formulate a formal Mini-Project Problem Statement with architecture and methodology.

# %% [markdown]
# ### 1. Landscape Survey of NLP Applications
# Evaluation across standard NLP problem domains.

# %%
import pandas as pd

nlp_applications = pd.DataFrame([
    {"Application": "Machine Translation", "Core Techniques": "Seq2Seq, Transformer (Encoder-Decoder)", "Real-World Example": "Google Translate, DeepL", "Impact in Legal Domain": "Translating international terms (e.g., cross-border e-commerce agreements)"},
    {"Application": "Text Summarization", "Core Techniques": "Extractive (LexRank/TextRank), Abstractive (BART/T5)", "Real-World Example": "Terms of Service; Didn't Read (ToS;DR)", "Impact in Legal Domain": "Condensing 30+ page contracts into actionable, high-risk bullet points"},
    {"Application": "Text Categorization", "Core Techniques": "TF-IDF + SVM, Naive Bayes, BERT Classification", "Real-World Example": "Spam filters, News categorization", "Impact in Legal Domain": "Categorizing clauses into Privacy, Liability, Termination, and Payment"},
    {"Application": "Question Answering / Chatbots", "Core Techniques": "Dense Retrieval, RAG, Intent Recognition", "Real-World Example": "LegalBot, DoNotPay, Intercom", "Impact in Legal Domain": "Enabling users to query contract obligations in natural plain language"},
    {"Application": "Sentiment Analysis", "Core Techniques": "VADER, RoBERTa, Aspect-Based Sentiment", "Real-World Example": "Product review analysis, Brand monitoring", "Impact in Legal Domain": "Detecting consumer sentiment and unfairness in user reviews vs terms"},
    {"Application": "Plagiarism & Grammar Checking", "Core Techniques": "N-Gram Overlap, Levenshtein Distance, T5", "Real-World Example": "Grammarly, Turnitin", "Impact in Legal Domain": "Ensuring clarity, consistency, and syntax precision in drafted agreements"}
])

display(nlp_applications)
# Out:
#                      Application  \
# 0            Machine Translation
# 1             Text Summarization
# 2            Text Categorization
# 3  Question Answering / Chatbots
# 4             Sentiment Analysis
# 5  Plagiarism & Grammar Checking
#
#                                      Core Techniques  \
# 0             Seq2Seq, Transformer (Encoder-Decoder)
# 1  Extractive (LexRank/TextRank), Abstractive (BA...
# 2     TF-IDF + SVM, Naive Bayes, BERT Classification
# 3           Dense Retrieval, RAG, Intent Recognition
# 4             VADER, RoBERTa, Aspect-Based Sentiment
# 5           N-Gram Overlap, Levenshtein Distance, T5
#
#                           Real-World Example  \
# 0                    Google Translate, DeepL
# 1     Terms of Service; Didn't Read (ToS;DR)
# 2          Spam filters, News categorization
# 3               LegalBot, DoNotPay, Intercom
# 4  Product review analysis, Brand monitoring
# 5                        Grammarly, Turnitin
#
# ...

# %% [markdown]
# ### 2. Mini-Project Formulation: Terms & Conditions Summarizer
# Structured definition of problem statement, datasets, literature review, and system architecture.

# %%
problem_charter = {
    "Project Title": "Automated Terms & Conditions Summarizer and Clause Risk Analyzer",
    "Problem Statement": (
        "End-users routinely accept complex, multi-page Terms and Conditions without reading them due to verbose legal jargon, "
        "unclear liability waivers, and obscure data privacy clauses. This project aims to build an end-to-end NLP system that "
        "automatically cleans, segments, categorizes contractual clauses, and produces concise, human-understandable summaries "
        "while flagging critical user risks (e.g. unilateral account termination, liability limits, and arbitration mandates)."
    ),
    "Dataset / Case Study": "Amazon Conditions of Use and Alibaba Free Membership Agreement & Terms of Use (1,500+ lines of legal text).",
    "System Architecture Stages": [
        "1. Ingestion: Raw multi-format text & HTML ingestion.",
        "2. Pre-processing: HTML stripping, negation preservation, monetary & section regex preservation, contraction expansion.",
        "3. Advanced Linguistic Processing: POS-aware Lemmatization, PII masking/entity anonymization, and Multilingual detection.",
        "4. Parsing: Shallow NP/VP chunking (rights vs obligations) & Deep Dependency SVO parsing.",
        "5. Summarization & Risk Scoring: Extractive key-sentence ranking and risk classification (High/Medium/Low)."
    ]
}

print("=== Mini-Project Formulation Charter ===\n")
for key, val in problem_charter.items():
    print(f"[{key}]:")
    if isinstance(val, list):
        for item in val:
            print(f"  {item}")
    else:
        print(f"  {val}")
    print()
# Out:
# === Mini-Project Formulation Charter ===
#
# [Project Title]:
#   Automated Terms & Conditions Summarizer and Clause Risk Analyzer
#
# [Problem Statement]:
#   End-users routinely accept complex, multi-page Terms and Conditions without reading them due to verbose legal jargon, unclear liability waivers, and obscure data privacy clauses. This project aims to build an end-to-end NLP system that automatically cleans, segments, categorizes contractual clauses, and produces concise, human-understandable summaries while flagging critical user risks (e.g. unilateral account termination, liability limits, and arbitration mandates).
#
# [Dataset / Case Study]:
#   Amazon Conditions of Use and Alibaba Free Membership Agreement & Terms of Use (1,500+ lines of legal text).
#
# [System Architecture Stages]:
#   1. Ingestion: Raw multi-format text & HTML ingestion.
#   2. Pre-processing: HTML stripping, negation preservation, monetary & section regex preservation, contraction expansion.
# ...
